# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
from torch_geometric.datasets import Planetoid, LRGBDataset
import scipy.sparse as sp
import numpy as np
from numpy.linalg import eigh

# %%
# Laplacian Positional Encoding (LapPE)
def laplacian_positional_encoding(edge_index, num_nodes, k=10):
    edge_index = edge_index.cpu().numpy()
    row, col = edge_index[0], edge_index[1]
    adj = sp.coo_matrix((np.ones(len(row)), (row, col)), shape=(num_nodes, num_nodes))
    degree = sp.diags(adj.sum(axis=1).A1)
    
    # Compute Laplacian
    laplacian = degree - adj
    eigenvalues, eigenvectors = eigh(laplacian.toarray())
    
    # Return top k eigenvectors as LapPE
    return torch.tensor(eigenvectors[:, :k], dtype=torch.float)

# %%
from torch_geometric.utils import to_scipy_sparse_matrix
from scipy.sparse.csgraph import laplacian as cs_laplacian
from scipy.sparse.linalg import eigsh
from numpy.linalg import eigh
import numpy as np
import torch

def compute_lap_pe(data, pe_dim=10, use_signnet=False):
    # Compute Laplacian and eigenvectors
    adj = to_scipy_sparse_matrix(data.edge_index, num_nodes=data.num_nodes).astype(float)
    lap = cs_laplacian(adj, normed=False)
    
    try:
        eigvals, eigvecs = eigsh(lap, k=pe_dim + 1, which='SM')
    except RuntimeError:
        eigvals, eigvecs = eigh(lap.toarray())
    
    pe = eigvecs[:, 1:pe_dim + 1]  # Exclude first eigenvector

    # Handle sign ambiguity (if not using SignNet, apply random sign flips)
    if not use_signnet:
        pe *= np.random.choice([-1, 1], size=(pe.shape[1],))

    # Add to data object
    data.lap_pe = torch.tensor(pe, dtype=torch.float)
    return data

# %%
class SignNet(torch.nn.Module):
    def __init__(self, in_features, out_features):
        super(SignNet, self).__init__()
        self.linear = torch.nn.Linear(in_features, out_features)

    def forward(self, x):
        return self.linear(x) + self.linear(-x)

# %%
def rwse(adj_matrix, k=10):
    powers = [adj_matrix**i for i in range(1, k + 1)]
    rwse_values = torch.stack([torch.trace(power).item() for power in powers], dim=0)
    return rwse_values

# %%
from torch_geometric.nn import TransformerConv
from torch_geometric.nn import global_mean_pool

class GraphTransformer(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, heads=8):  # Use 8 heads as per the task
        super(GraphTransformer, self).__init__()
        self.transformer = TransformerConv(in_channels, hidden_channels, heads=heads)
        self.out_channels = hidden_channels * heads  # 64 * 8 = 512

    def forward(self, x, edge_index):
        return F.relu(self.transformer(x, edge_index))


class GraphTransformerClassifier(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes, task="node"):
        super(GraphTransformerClassifier, self).__init__()
        self.transformer = GraphTransformer(in_channels, hidden_channels, heads=8)
        self.reduce_dim = torch.nn.Linear(hidden_channels * 8, hidden_channels)  # 512 -> 64
        self.task = task
        self.pool = global_mean_pool if task == "graph" else None
        self.fc = torch.nn.Linear(hidden_channels, num_classes)

    def forward(self, x, edge_index, batch=None):
        x = self.transformer(x, edge_index)
        x = self.reduce_dim(x)  # Reduce dimension from 512 to 64
        if self.task == "graph":
            x = self.pool(x, batch)  # Global mean pooling for graph-level tasks
        return self.fc(x)

# %%
# Example with Cora Dataset
cora_dataset = Planetoid(root='./dataset/cora', name='Cora')
cora_data = cora_dataset[0]

print(f"Original features: {cora_data.num_node_features}")  # Should be 1433

# Compute LapPE for Cora dataset
lap_pe = laplacian_positional_encoding(cora_data.edge_index, cora_data.num_nodes, k=10)
cora_data.x = torch.cat([cora_data.x, lap_pe], dim=1)  # Concatenate LapPE with original features

print(f"Laplacian Positional Encoding shape: {lap_pe.shape}")  # Should be [2708, 10]
print(f"Concatenated features shape: {cora_data.x.shape}")  # Should be [2708, 1443]
print(f"New features: {cora_data.num_node_features}")  # Should be 1433
# Out:
# c:\Users\Akshat\anaconda3\envs\lua_torch\lib\site-packages\torch_geometric\data\dataset.py:238: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_transform):
# c:\Users\Akshat\anaconda3\envs\lua_torch\lib\site-packages\torch_geometric\data\dataset.py:246: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   if osp.exists(f) and torch.load(f) != _repr(self.pre_filter):
# c:\Users\Akshat\anaconda3\envs\lua_torch\lib\site-packages\torch_geometric\io\fs.py:215: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location)
# Original features: 1433
# Laplacian Positional Encoding shape: torch.Size([2708, 10])
# Concatenated features shape: torch.Size([2708, 1443])
# Original features: 1443

# %%
def train(model, loader, optimizer, criterion, task="node"):
    model.train()
    total_loss = 0

    for batch in loader:  # Batch comes from DataLoader
        optimizer.zero_grad()

        if task == "node":
            out = model(batch.x, batch.edge_index)
            loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
        else:  # Graph classification
            out = model(batch.x, batch.edge_index, batch.batch)
            loss = criterion(out, batch.y)

        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    return total_loss / len(loader)


def evaluate(model, loader, criterion, task="node"):
    model.eval()
    correct = 0
    total_loss = 0

    # Handle single graph datasets
    if len(loader) == 1:  # Single graph case
        graph_data = loader.dataset[0]  # Access the single graph
        total_nodes = graph_data.num_nodes if task == "node" else 1  # Total nodes for node classification
    else:
        total_nodes = sum(batch.num_nodes for batch in loader.dataset)

    for batch in loader:
        with torch.no_grad():
            if task == "node":
                out = model(batch.x, batch.edge_index)
                pred = out.argmax(dim=1)
                correct += (pred[batch.test_mask] == batch.y[batch.test_mask]).sum().item()
                loss = criterion(out[batch.test_mask], batch.y[batch.test_mask])
            else:  # Graph classification
                out = model(batch.x, batch.edge_index, batch.batch)
                pred = out.argmax(dim=1)
                correct += (pred == batch.y).sum().item()
                loss = criterion(out, batch.y)

            total_loss += loss.item()

    accuracy = correct / total_nodes
    return total_loss / len(loader), accuracy

# %%
cora_model = GraphTransformerClassifier(
    in_channels=cora_data.num_node_features,
    hidden_channels=64,
    out_channels=32,
    num_classes=cora_dataset.num_classes,
    task="node"
).to('cuda')

# %%
# Initialize model, optimizer, and loss function
optimizer = torch.optim.AdamW(cora_model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = torch.nn.CrossEntropyLoss()

from torch_geometric.loader import DataLoader

cora_loader = DataLoader([cora_data.cuda()], batch_size=1)  # Single graph wrapped in DataLoader

# Training loop
for epoch in range(500):
    train_loss = train(cora_model, cora_loader, optimizer, criterion, task="node")
    test_loss, test_accuracy = evaluate(cora_model, cora_loader, criterion, task="node")

    print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1, Train Loss: 1.9498, Test Loss: 1.9174, Test Accuracy: 0.1178
# Epoch 2, Train Loss: 1.9428, Test Loss: 1.9161, Test Accuracy: 0.1178
# Epoch 3, Train Loss: 1.9358, Test Loss: 1.9147, Test Accuracy: 0.1178
# Epoch 4, Train Loss: 1.9289, Test Loss: 1.9133, Test Accuracy: 0.1178
# Epoch 5, Train Loss: 1.9220, Test Loss: 1.9119, Test Accuracy: 0.1178
# Epoch 6, Train Loss: 1.9151, Test Loss: 1.9105, Test Accuracy: 0.1178
# Epoch 7, Train Loss: 1.9082, Test Loss: 1.9090, Test Accuracy: 0.1178
# Epoch 8, Train Loss: 1.9013, Test Loss: 1.9076, Test Accuracy: 0.1178
# Epoch 9, Train Loss: 1.8944, Test Loss: 1.9060, Test Accuracy: 0.1178
# Epoch 10, Train Loss: 1.8874, Test Loss: 1.9045, Test Accuracy: 0.1178
# Epoch 11, Train Loss: 1.8804, Test Loss: 1.9029, Test Accuracy: 0.1178
# Epoch 12, Train Loss: 1.8732, Test Loss: 1.9012, Test Accuracy: 0.1178
# Epoch 13, Train Loss: 1.8659, Test Loss: 1.8995, Test Accuracy: 0.1182
# Epoch 14, Train Loss: 1.8585, Test Loss: 1.8978, Test Accuracy: 0.1182
# Epoch 15, Train Loss: 1.8510, Test Loss: 1.8960, Test Accuracy: 0.1185
# Epoch 16, Train Loss: 1.8433, Test Loss: 1.8941, Test Accuracy: 0.1193
# Epoch 17, Train Loss: 1.8355, Test Loss: 1.8921, Test Accuracy: 0.1196
# Epoch 18, Train Loss: 1.8274, Test Loss: 1.8901, Test Accuracy: 0.1211
# Epoch 19, Train Loss: 1.8192, Test Loss: 1.8880, Test Accuracy: 0.1263
# Epoch 20, Train Loss: 1.8108, Test Loss: 1.8858, Test Accuracy: 0.1292
# Epoch 21, Train Loss: 1.8021, Test Loss: 1.8835, Test Accuracy: 0.1311
# Epoch 22, Train Loss: 1.7932, Test Loss: 1.8812, Test Accuracy: 0.1352
# Epoch 23, Train Loss: 1.7840, Test Loss: 1.8787, Test Accuracy: 0.1396
# Epoch 24, Train Loss: 1.7746, Test Loss: 1.8761, Test Accuracy: 0.1459
# Epoch 25, Train Loss: 1.7649, Test Loss: 1.8735, Test Accuracy: 0.1488
# Epoch 26, Train Loss: 1.7549, Test Loss: 1.8707, Test Accuracy: 0.1540
# Epoch 27, Train Loss: 1.7446, Test Loss: 1.8678, Test Accuracy: 0.1599
# Epoch 28, Train Loss: 1.7340, Test Loss: 1.8648, Test Accuracy: 0.1677
# Epoch 29, Train Loss: 1.7231, Test Loss: 1.8617, Test Accuracy: 0.1736
# Epoch 30, Train Loss: 1.7118, Test Loss: 1.8585, Test Accuracy: 0.1791
# Epoch 31, Train Loss: 1.7002, Test Loss: 1.8551, Test Accuracy: 0.1835
# Epoch 32, Train Loss: 1.6883, Test Loss: 1.8516, Test Accuracy: 0.1894
# Epoch 33, Train Loss: 1.6760, Test Loss: 1.8480, Test Accuracy: 0.1957
# Epoch 34, Train Loss: 1.6634, Test Loss: 1.8443, Test Accuracy: 0.2027
# Epoch 35, Train Loss: 1.6504, Test Loss: 1.8404, Test Accuracy: 0.2094
# Epoch 36, Train Loss: 1.6371, Test Loss: 1.8364, Test Accuracy: 0.2127
# Epoch 37, Train Loss: 1.6233, Test Loss: 1.8323, Test Accuracy: 0.2205
# Epoch 38, Train Loss: 1.6092, Test Loss: 1.8280, Test Accuracy: 0.2278
# Epoch 39, Train Loss: 1.5948, Test Loss: 1.8236, Test Accuracy: 0.2338
# Epoch 40, Train Loss: 1.5799, Test Loss: 1.8190, Test Accuracy: 0.2382
# Epoch 41, Train Loss: 1.5647, Test Loss: 1.8143, Test Accuracy: 0.2459
# Epoch 42, Train Loss: 1.5491, Test Loss: 1.8094, Test Accuracy: 0.2500
# Epoch 43, Train Loss: 1.5331, Test Loss: 1.8044, Test Accuracy: 0.2548
# Epoch 44, Train Loss: 1.5168, Test Loss: 1.7993, Test Accuracy: 0.2581
# Epoch 45, Train Loss: 1.5000, Test Loss: 1.7940, Test Accuracy: 0.2592
# Epoch 46, Train Loss: 1.4829, Test Loss: 1.7885, Test Accuracy: 0.2596
# Epoch 47, Train Loss: 1.4654, Test Loss: 1.7829, Test Accuracy: 0.2607
# Epoch 48, Train Loss: 1.4475, Test Loss: 1.7772, Test Accuracy: 0.2592
# Epoch 49, Train Loss: 1.4293, Test Loss: 1.7712, Test Accuracy: 0.2622
# Epoch 50, Train Loss: 1.4107, Test Loss: 1.7651, Test Accuracy: 0.2640
# Epoch 51, Train Loss: 1.3917, Test Loss: 1.7589, Test Accuracy: 0.2644
# Epoch 52, Train Loss: 1.3725, Test Loss: 1.7525, Test Accuracy: 0.2648
# Epoch 53, Train Loss: 1.3529, Test Loss: 1.7460, Test Accuracy: 0.2666
# Epoch 54, Train Loss: 1.3330, Test Loss: 1.7393, Test Accuracy: 0.2670
# Epoch 55, Train Loss: 1.3128, Test Loss: 1.7325, Test Accuracy: 0.2670
# Epoch 56, Train Loss: 1.2923, Test Loss: 1.7255, Test Accuracy: 0.2670
# Epoch 57, Train Loss: 1.2715, Test Loss: 1.7183, Test Accuracy: 0.2655
# Epoch 58, Train Loss: 1.2504, Test Loss: 1.7110, Test Accuracy: 0.2648
# Epoch 59, Train Loss: 1.2291, Test Loss: 1.7036, Test Accuracy: 0.2648
# Epoch 60, Train Loss: 1.2075, Test Loss: 1.6960, Test Accuracy: 0.2640
# Epoch 61, Train Loss: 1.1858, Test Loss: 1.6883, Test Accuracy: 0.2640
# Epoch 62, Train Loss: 1.1638, Test Loss: 1.6805, Test Accuracy: 0.2655
# Epoch 63, Train Loss: 1.1417, Test Loss: 1.6725, Test Accuracy: 0.2651
# Epoch 64, Train Loss: 1.1195, Test Loss: 1.6644, Test Accuracy: 0.2651
# Epoch 65, Train Loss: 1.0971, Test Loss: 1.6562, Test Accuracy: 0.2651
# Epoch 66, Train Loss: 1.0746, Test Loss: 1.6479, Test Accuracy: 0.2648
# Epoch 67, Train Loss: 1.0520, Test Loss: 1.6394, Test Accuracy: 0.2651
# Epoch 68, Train Loss: 1.0294, Test Loss: 1.6309, Test Accuracy: 0.2651
# Epoch 69, Train Loss: 1.0067, Test Loss: 1.6222, Test Accuracy: 0.2651
# Epoch 70, Train Loss: 0.9840, Test Loss: 1.6134, Test Accuracy: 0.2659
# Epoch 71, Train Loss: 0.9614, Test Loss: 1.6046, Test Accuracy: 0.2655
# Epoch 72, Train Loss: 0.9388, Test Loss: 1.5957, Test Accuracy: 0.2651
# Epoch 73, Train Loss: 0.9162, Test Loss: 1.5866, Test Accuracy: 0.2648
# Epoch 74, Train Loss: 0.8938, Test Loss: 1.5776, Test Accuracy: 0.2644
# Epoch 75, Train Loss: 0.8714, Test Loss: 1.5684, Test Accuracy: 0.2644
# Epoch 76, Train Loss: 0.8492, Test Loss: 1.5592, Test Accuracy: 0.2648
# Epoch 77, Train Loss: 0.8272, Test Loss: 1.5499, Test Accuracy: 0.2651
# Epoch 78, Train Loss: 0.8053, Test Loss: 1.5406, Test Accuracy: 0.2651
# Epoch 79, Train Loss: 0.7837, Test Loss: 1.5312, Test Accuracy: 0.2655
# Epoch 80, Train Loss: 0.7623, Test Loss: 1.5218, Test Accuracy: 0.2651
# Epoch 81, Train Loss: 0.7411, Test Loss: 1.5124, Test Accuracy: 0.2648
# Epoch 82, Train Loss: 0.7202, Test Loss: 1.5030, Test Accuracy: 0.2648
# Epoch 83, Train Loss: 0.6996, Test Loss: 1.4935, Test Accuracy: 0.2644
# Epoch 84, Train Loss: 0.6793, Test Loss: 1.4841, Test Accuracy: 0.2644
# Epoch 85, Train Loss: 0.6593, Test Loss: 1.4746, Test Accuracy: 0.2655
# Epoch 86, Train Loss: 0.6397, Test Loss: 1.4652, Test Accuracy: 0.2662
# Epoch 87, Train Loss: 0.6204, Test Loss: 1.4558, Test Accuracy: 0.2666
# Epoch 88, Train Loss: 0.6015, Test Loss: 1.4464, Test Accuracy: 0.2674
# Epoch 89, Train Loss: 0.5830, Test Loss: 1.4371, Test Accuracy: 0.2685
# Epoch 90, Train Loss: 0.5649, Test Loss: 1.4278, Test Accuracy: 0.2681
# Epoch 91, Train Loss: 0.5471, Test Loss: 1.4185, Test Accuracy: 0.2681
# Epoch 92, Train Loss: 0.5298, Test Loss: 1.4093, Test Accuracy: 0.2681
# Epoch 93, Train Loss: 0.5129, Test Loss: 1.4002, Test Accuracy: 0.2681
# Epoch 94, Train Loss: 0.4964, Test Loss: 1.3912, Test Accuracy: 0.2688
# Epoch 95, Train Loss: 0.4804, Test Loss: 1.3822, Test Accuracy: 0.2692
# Epoch 96, Train Loss: 0.4647, Test Loss: 1.3734, Test Accuracy: 0.2699
# Epoch 97, Train Loss: 0.4495, Test Loss: 1.3646, Test Accuracy: 0.2707
# Epoch 98, Train Loss: 0.4348, Test Loss: 1.3559, Test Accuracy: 0.2710
# Epoch 99, Train Loss: 0.4204, Test Loss: 1.3473, Test Accuracy: 0.2710
# Epoch 100, Train Loss: 0.4065, Test Loss: 1.3389, Test Accuracy: 0.2710
# Epoch 101, Train Loss: 0.3930, Test Loss: 1.3305, Test Accuracy: 0.2714
# Epoch 102, Train Loss: 0.3800, Test Loss: 1.3223, Test Accuracy: 0.2718
# Epoch 103, Train Loss: 0.3673, Test Loss: 1.3142, Test Accuracy: 0.2722
# Epoch 104, Train Loss: 0.3551, Test Loss: 1.3062, Test Accuracy: 0.2725
# Epoch 105, Train Loss: 0.3433, Test Loss: 1.2984, Test Accuracy: 0.2729
# Epoch 106, Train Loss: 0.3319, Test Loss: 1.2907, Test Accuracy: 0.2729
# Epoch 107, Train Loss: 0.3208, Test Loss: 1.2831, Test Accuracy: 0.2729
# Epoch 108, Train Loss: 0.3102, Test Loss: 1.2757, Test Accuracy: 0.2733
# Epoch 109, Train Loss: 0.2999, Test Loss: 1.2684, Test Accuracy: 0.2729
# Epoch 110, Train Loss: 0.2900, Test Loss: 1.2613, Test Accuracy: 0.2729
# Epoch 111, Train Loss: 0.2805, Test Loss: 1.2543, Test Accuracy: 0.2722
# Epoch 112, Train Loss: 0.2713, Test Loss: 1.2474, Test Accuracy: 0.2725
# Epoch 113, Train Loss: 0.2625, Test Loss: 1.2407, Test Accuracy: 0.2722
# Epoch 114, Train Loss: 0.2540, Test Loss: 1.2342, Test Accuracy: 0.2725
# Epoch 115, Train Loss: 0.2458, Test Loss: 1.2277, Test Accuracy: 0.2725
# Epoch 116, Train Loss: 0.2379, Test Loss: 1.2214, Test Accuracy: 0.2733
# Epoch 117, Train Loss: 0.2303, Test Loss: 1.2153, Test Accuracy: 0.2736
# Epoch 118, Train Loss: 0.2231, Test Loss: 1.2093, Test Accuracy: 0.2736
# Epoch 119, Train Loss: 0.2160, Test Loss: 1.2034, Test Accuracy: 0.2736
# Epoch 120, Train Loss: 0.2093, Test Loss: 1.1977, Test Accuracy: 0.2736
# Epoch 121, Train Loss: 0.2028, Test Loss: 1.1921, Test Accuracy: 0.2736
# Epoch 122, Train Loss: 0.1966, Test Loss: 1.1866, Test Accuracy: 0.2736
# Epoch 123, Train Loss: 0.1906, Test Loss: 1.1812, Test Accuracy: 0.2736
# Epoch 124, Train Loss: 0.1849, Test Loss: 1.1760, Test Accuracy: 0.2736
# Epoch 125, Train Loss: 0.1793, Test Loss: 1.1709, Test Accuracy: 0.2736
# Epoch 126, Train Loss: 0.1740, Test Loss: 1.1659, Test Accuracy: 0.2736
# Epoch 127, Train Loss: 0.1689, Test Loss: 1.1611, Test Accuracy: 0.2733
# Epoch 128, Train Loss: 0.1640, Test Loss: 1.1563, Test Accuracy: 0.2736
# Epoch 129, Train Loss: 0.1593, Test Loss: 1.1517, Test Accuracy: 0.2736
# Epoch 130, Train Loss: 0.1547, Test Loss: 1.1472, Test Accuracy: 0.2736
# Epoch 131, Train Loss: 0.1504, Test Loss: 1.1428, Test Accuracy: 0.2733
# Epoch 132, Train Loss: 0.1462, Test Loss: 1.1385, Test Accuracy: 0.2733
# Epoch 133, Train Loss: 0.1421, Test Loss: 1.1343, Test Accuracy: 0.2733
# Epoch 134, Train Loss: 0.1383, Test Loss: 1.1302, Test Accuracy: 0.2733
# Epoch 135, Train Loss: 0.1345, Test Loss: 1.1262, Test Accuracy: 0.2733
# Epoch 136, Train Loss: 0.1309, Test Loss: 1.1223, Test Accuracy: 0.2733
# Epoch 137, Train Loss: 0.1274, Test Loss: 1.1185, Test Accuracy: 0.2733
# Epoch 138, Train Loss: 0.1241, Test Loss: 1.1147, Test Accuracy: 0.2733
# Epoch 139, Train Loss: 0.1209, Test Loss: 1.1111, Test Accuracy: 0.2733
# Epoch 140, Train Loss: 0.1178, Test Loss: 1.1075, Test Accuracy: 0.2733
# Epoch 141, Train Loss: 0.1148, Test Loss: 1.1041, Test Accuracy: 0.2729
# Epoch 142, Train Loss: 0.1119, Test Loss: 1.1007, Test Accuracy: 0.2729
# Epoch 143, Train Loss: 0.1092, Test Loss: 1.0973, Test Accuracy: 0.2729
# Epoch 144, Train Loss: 0.1065, Test Loss: 1.0941, Test Accuracy: 0.2729
# Epoch 145, Train Loss: 0.1039, Test Loss: 1.0909, Test Accuracy: 0.2729
# Epoch 146, Train Loss: 0.1014, Test Loss: 1.0878, Test Accuracy: 0.2729
# Epoch 147, Train Loss: 0.0990, Test Loss: 1.0848, Test Accuracy: 0.2729
# Epoch 148, Train Loss: 0.0967, Test Loss: 1.0818, Test Accuracy: 0.2729
# Epoch 149, Train Loss: 0.0944, Test Loss: 1.0789, Test Accuracy: 0.2729
# Epoch 150, Train Loss: 0.0923, Test Loss: 1.0760, Test Accuracy: 0.2725
# Epoch 151, Train Loss: 0.0902, Test Loss: 1.0732, Test Accuracy: 0.2729
# Epoch 152, Train Loss: 0.0882, Test Loss: 1.0705, Test Accuracy: 0.2729
# Epoch 153, Train Loss: 0.0862, Test Loss: 1.0678, Test Accuracy: 0.2729
# Epoch 154, Train Loss: 0.0843, Test Loss: 1.0652, Test Accuracy: 0.2733
# Epoch 155, Train Loss: 0.0825, Test Loss: 1.0626, Test Accuracy: 0.2733
# Epoch 156, Train Loss: 0.0807, Test Loss: 1.0601, Test Accuracy: 0.2733
# Epoch 157, Train Loss: 0.0790, Test Loss: 1.0577, Test Accuracy: 0.2733
# Epoch 158, Train Loss: 0.0774, Test Loss: 1.0552, Test Accuracy: 0.2733
# Epoch 159, Train Loss: 0.0757, Test Loss: 1.0529, Test Accuracy: 0.2736
# Epoch 160, Train Loss: 0.0742, Test Loss: 1.0505, Test Accuracy: 0.2733
# Epoch 161, Train Loss: 0.0727, Test Loss: 1.0482, Test Accuracy: 0.2729
# Epoch 162, Train Loss: 0.0712, Test Loss: 1.0460, Test Accuracy: 0.2725
# Epoch 163, Train Loss: 0.0698, Test Loss: 1.0438, Test Accuracy: 0.2729
# Epoch 164, Train Loss: 0.0684, Test Loss: 1.0416, Test Accuracy: 0.2729
# Epoch 165, Train Loss: 0.0671, Test Loss: 1.0395, Test Accuracy: 0.2729
# Epoch 166, Train Loss: 0.0658, Test Loss: 1.0374, Test Accuracy: 0.2725
# Epoch 167, Train Loss: 0.0645, Test Loss: 1.0354, Test Accuracy: 0.2725
# Epoch 168, Train Loss: 0.0633, Test Loss: 1.0334, Test Accuracy: 0.2725
# Epoch 169, Train Loss: 0.0621, Test Loss: 1.0314, Test Accuracy: 0.2729
# Epoch 170, Train Loss: 0.0610, Test Loss: 1.0295, Test Accuracy: 0.2729
# Epoch 171, Train Loss: 0.0599, Test Loss: 1.0276, Test Accuracy: 0.2729
# Epoch 172, Train Loss: 0.0588, Test Loss: 1.0257, Test Accuracy: 0.2729
# Epoch 173, Train Loss: 0.0577, Test Loss: 1.0239, Test Accuracy: 0.2729
# Epoch 174, Train Loss: 0.0567, Test Loss: 1.0221, Test Accuracy: 0.2729
# Epoch 175, Train Loss: 0.0557, Test Loss: 1.0203, Test Accuracy: 0.2729
# Epoch 176, Train Loss: 0.0547, Test Loss: 1.0186, Test Accuracy: 0.2729
# Epoch 177, Train Loss: 0.0538, Test Loss: 1.0169, Test Accuracy: 0.2729
# Epoch 178, Train Loss: 0.0528, Test Loss: 1.0152, Test Accuracy: 0.2729
# Epoch 179, Train Loss: 0.0519, Test Loss: 1.0135, Test Accuracy: 0.2729
# Epoch 180, Train Loss: 0.0510, Test Loss: 1.0119, Test Accuracy: 0.2725
# Epoch 181, Train Loss: 0.0502, Test Loss: 1.0103, Test Accuracy: 0.2725
# Epoch 182, Train Loss: 0.0494, Test Loss: 1.0087, Test Accuracy: 0.2725
# Epoch 183, Train Loss: 0.0485, Test Loss: 1.0071, Test Accuracy: 0.2725
# Epoch 184, Train Loss: 0.0478, Test Loss: 1.0056, Test Accuracy: 0.2725
# Epoch 185, Train Loss: 0.0470, Test Loss: 1.0041, Test Accuracy: 0.2725
# Epoch 186, Train Loss: 0.0462, Test Loss: 1.0026, Test Accuracy: 0.2725
# Epoch 187, Train Loss: 0.0455, Test Loss: 1.0011, Test Accuracy: 0.2729
# Epoch 188, Train Loss: 0.0448, Test Loss: 0.9997, Test Accuracy: 0.2729
# Epoch 189, Train Loss: 0.0441, Test Loss: 0.9983, Test Accuracy: 0.2733
# Epoch 190, Train Loss: 0.0434, Test Loss: 0.9969, Test Accuracy: 0.2733
# Epoch 191, Train Loss: 0.0427, Test Loss: 0.9955, Test Accuracy: 0.2733
# Epoch 192, Train Loss: 0.0421, Test Loss: 0.9942, Test Accuracy: 0.2729
# Epoch 193, Train Loss: 0.0414, Test Loss: 0.9928, Test Accuracy: 0.2729
# Epoch 194, Train Loss: 0.0408, Test Loss: 0.9915, Test Accuracy: 0.2729
# Epoch 195, Train Loss: 0.0402, Test Loss: 0.9902, Test Accuracy: 0.2729
# Epoch 196, Train Loss: 0.0396, Test Loss: 0.9889, Test Accuracy: 0.2729
# Epoch 197, Train Loss: 0.0390, Test Loss: 0.9877, Test Accuracy: 0.2729
# Epoch 198, Train Loss: 0.0385, Test Loss: 0.9864, Test Accuracy: 0.2729
# Epoch 199, Train Loss: 0.0379, Test Loss: 0.9852, Test Accuracy: 0.2729
# Epoch 200, Train Loss: 0.0374, Test Loss: 0.9840, Test Accuracy: 0.2729
# Epoch 201, Train Loss: 0.0368, Test Loss: 0.9828, Test Accuracy: 0.2729
# Epoch 202, Train Loss: 0.0363, Test Loss: 0.9816, Test Accuracy: 0.2729
# Epoch 203, Train Loss: 0.0358, Test Loss: 0.9804, Test Accuracy: 0.2729
# Epoch 204, Train Loss: 0.0353, Test Loss: 0.9793, Test Accuracy: 0.2729
# Epoch 205, Train Loss: 0.0348, Test Loss: 0.9782, Test Accuracy: 0.2729
# Epoch 206, Train Loss: 0.0343, Test Loss: 0.9770, Test Accuracy: 0.2729
# Epoch 207, Train Loss: 0.0339, Test Loss: 0.9759, Test Accuracy: 0.2729
# Epoch 208, Train Loss: 0.0334, Test Loss: 0.9749, Test Accuracy: 0.2729
# Epoch 209, Train Loss: 0.0330, Test Loss: 0.9738, Test Accuracy: 0.2729
# Epoch 210, Train Loss: 0.0325, Test Loss: 0.9727, Test Accuracy: 0.2729
# Epoch 211, Train Loss: 0.0321, Test Loss: 0.9717, Test Accuracy: 0.2725
# Epoch 212, Train Loss: 0.0317, Test Loss: 0.9706, Test Accuracy: 0.2725
# Epoch 213, Train Loss: 0.0312, Test Loss: 0.9696, Test Accuracy: 0.2725
# Epoch 214, Train Loss: 0.0308, Test Loss: 0.9686, Test Accuracy: 0.2725
# Epoch 215, Train Loss: 0.0304, Test Loss: 0.9676, Test Accuracy: 0.2725
# Epoch 216, Train Loss: 0.0301, Test Loss: 0.9666, Test Accuracy: 0.2725
# Epoch 217, Train Loss: 0.0297, Test Loss: 0.9657, Test Accuracy: 0.2725
# Epoch 218, Train Loss: 0.0293, Test Loss: 0.9647, Test Accuracy: 0.2722
# Epoch 219, Train Loss: 0.0289, Test Loss: 0.9638, Test Accuracy: 0.2722
# Epoch 220, Train Loss: 0.0286, Test Loss: 0.9628, Test Accuracy: 0.2722
# Epoch 221, Train Loss: 0.0282, Test Loss: 0.9619, Test Accuracy: 0.2722
# Epoch 222, Train Loss: 0.0279, Test Loss: 0.9610, Test Accuracy: 0.2722
# Epoch 223, Train Loss: 0.0275, Test Loss: 0.9601, Test Accuracy: 0.2722
# Epoch 224, Train Loss: 0.0272, Test Loss: 0.9592, Test Accuracy: 0.2722
# Epoch 225, Train Loss: 0.0269, Test Loss: 0.9583, Test Accuracy: 0.2722
# Epoch 226, Train Loss: 0.0265, Test Loss: 0.9575, Test Accuracy: 0.2722
# Epoch 227, Train Loss: 0.0262, Test Loss: 0.9566, Test Accuracy: 0.2722
# Epoch 228, Train Loss: 0.0259, Test Loss: 0.9558, Test Accuracy: 0.2722
# Epoch 229, Train Loss: 0.0256, Test Loss: 0.9549, Test Accuracy: 0.2722
# Epoch 230, Train Loss: 0.0253, Test Loss: 0.9541, Test Accuracy: 0.2722
# Epoch 231, Train Loss: 0.0250, Test Loss: 0.9533, Test Accuracy: 0.2722
# Epoch 232, Train Loss: 0.0247, Test Loss: 0.9525, Test Accuracy: 0.2722
# Epoch 233, Train Loss: 0.0244, Test Loss: 0.9517, Test Accuracy: 0.2722
# Epoch 234, Train Loss: 0.0242, Test Loss: 0.9509, Test Accuracy: 0.2718
# Epoch 235, Train Loss: 0.0239, Test Loss: 0.9501, Test Accuracy: 0.2718
# Epoch 236, Train Loss: 0.0236, Test Loss: 0.9493, Test Accuracy: 0.2718
# Epoch 237, Train Loss: 0.0234, Test Loss: 0.9485, Test Accuracy: 0.2714
# Epoch 238, Train Loss: 0.0231, Test Loss: 0.9478, Test Accuracy: 0.2714
# Epoch 239, Train Loss: 0.0228, Test Loss: 0.9470, Test Accuracy: 0.2714
# Epoch 240, Train Loss: 0.0226, Test Loss: 0.9463, Test Accuracy: 0.2710
# Epoch 241, Train Loss: 0.0223, Test Loss: 0.9456, Test Accuracy: 0.2710
# Epoch 242, Train Loss: 0.0221, Test Loss: 0.9448, Test Accuracy: 0.2710
# Epoch 243, Train Loss: 0.0219, Test Loss: 0.9441, Test Accuracy: 0.2710
# Epoch 244, Train Loss: 0.0216, Test Loss: 0.9434, Test Accuracy: 0.2710
# Epoch 245, Train Loss: 0.0214, Test Loss: 0.9427, Test Accuracy: 0.2710
# Epoch 246, Train Loss: 0.0212, Test Loss: 0.9420, Test Accuracy: 0.2710
# Epoch 247, Train Loss: 0.0209, Test Loss: 0.9413, Test Accuracy: 0.2710
# Epoch 248, Train Loss: 0.0207, Test Loss: 0.9406, Test Accuracy: 0.2710
# Epoch 249, Train Loss: 0.0205, Test Loss: 0.9400, Test Accuracy: 0.2710
# Epoch 250, Train Loss: 0.0203, Test Loss: 0.9393, Test Accuracy: 0.2707
# Epoch 251, Train Loss: 0.0201, Test Loss: 0.9386, Test Accuracy: 0.2707
# Epoch 252, Train Loss: 0.0199, Test Loss: 0.9380, Test Accuracy: 0.2707
# Epoch 253, Train Loss: 0.0197, Test Loss: 0.9373, Test Accuracy: 0.2707
# Epoch 254, Train Loss: 0.0195, Test Loss: 0.9367, Test Accuracy: 0.2703
# Epoch 255, Train Loss: 0.0193, Test Loss: 0.9361, Test Accuracy: 0.2707
# Epoch 256, Train Loss: 0.0191, Test Loss: 0.9354, Test Accuracy: 0.2707
# Epoch 257, Train Loss: 0.0189, Test Loss: 0.9348, Test Accuracy: 0.2707
# Epoch 258, Train Loss: 0.0187, Test Loss: 0.9342, Test Accuracy: 0.2707
# Epoch 259, Train Loss: 0.0185, Test Loss: 0.9336, Test Accuracy: 0.2707
# Epoch 260, Train Loss: 0.0183, Test Loss: 0.9330, Test Accuracy: 0.2707
# Epoch 261, Train Loss: 0.0181, Test Loss: 0.9324, Test Accuracy: 0.2707
# Epoch 262, Train Loss: 0.0179, Test Loss: 0.9318, Test Accuracy: 0.2707
# Epoch 263, Train Loss: 0.0178, Test Loss: 0.9312, Test Accuracy: 0.2707
# Epoch 264, Train Loss: 0.0176, Test Loss: 0.9307, Test Accuracy: 0.2707
# Epoch 265, Train Loss: 0.0174, Test Loss: 0.9301, Test Accuracy: 0.2707
# Epoch 266, Train Loss: 0.0173, Test Loss: 0.9295, Test Accuracy: 0.2707
# Epoch 267, Train Loss: 0.0171, Test Loss: 0.9290, Test Accuracy: 0.2707
# Epoch 268, Train Loss: 0.0169, Test Loss: 0.9284, Test Accuracy: 0.2707
# Epoch 269, Train Loss: 0.0168, Test Loss: 0.9278, Test Accuracy: 0.2707
# Epoch 270, Train Loss: 0.0166, Test Loss: 0.9273, Test Accuracy: 0.2707
# Epoch 271, Train Loss: 0.0165, Test Loss: 0.9268, Test Accuracy: 0.2707
# Epoch 272, Train Loss: 0.0163, Test Loss: 0.9262, Test Accuracy: 0.2707
# Epoch 273, Train Loss: 0.0161, Test Loss: 0.9257, Test Accuracy: 0.2707
# Epoch 274, Train Loss: 0.0160, Test Loss: 0.9252, Test Accuracy: 0.2707
# Epoch 275, Train Loss: 0.0158, Test Loss: 0.9247, Test Accuracy: 0.2707
# Epoch 276, Train Loss: 0.0157, Test Loss: 0.9241, Test Accuracy: 0.2707
# Epoch 277, Train Loss: 0.0156, Test Loss: 0.9236, Test Accuracy: 0.2707
# Epoch 278, Train Loss: 0.0154, Test Loss: 0.9231, Test Accuracy: 0.2710
# Epoch 279, Train Loss: 0.0153, Test Loss: 0.9226, Test Accuracy: 0.2710
# Epoch 280, Train Loss: 0.0151, Test Loss: 0.9221, Test Accuracy: 0.2710
# Epoch 281, Train Loss: 0.0150, Test Loss: 0.9216, Test Accuracy: 0.2710
# Epoch 282, Train Loss: 0.0149, Test Loss: 0.9212, Test Accuracy: 0.2710
# Epoch 283, Train Loss: 0.0147, Test Loss: 0.9207, Test Accuracy: 0.2707
# Epoch 284, Train Loss: 0.0146, Test Loss: 0.9202, Test Accuracy: 0.2707
# Epoch 285, Train Loss: 0.0145, Test Loss: 0.9197, Test Accuracy: 0.2707
# Epoch 286, Train Loss: 0.0144, Test Loss: 0.9193, Test Accuracy: 0.2707
# Epoch 287, Train Loss: 0.0142, Test Loss: 0.9188, Test Accuracy: 0.2707
# Epoch 288, Train Loss: 0.0141, Test Loss: 0.9183, Test Accuracy: 0.2703
# Epoch 289, Train Loss: 0.0140, Test Loss: 0.9179, Test Accuracy: 0.2707
# Epoch 290, Train Loss: 0.0139, Test Loss: 0.9174, Test Accuracy: 0.2707
# Epoch 291, Train Loss: 0.0137, Test Loss: 0.9170, Test Accuracy: 0.2707
# Epoch 292, Train Loss: 0.0136, Test Loss: 0.9165, Test Accuracy: 0.2707
# Epoch 293, Train Loss: 0.0135, Test Loss: 0.9161, Test Accuracy: 0.2707
# Epoch 294, Train Loss: 0.0134, Test Loss: 0.9156, Test Accuracy: 0.2707
# Epoch 295, Train Loss: 0.0133, Test Loss: 0.9152, Test Accuracy: 0.2707
# Epoch 296, Train Loss: 0.0132, Test Loss: 0.9148, Test Accuracy: 0.2707
# Epoch 297, Train Loss: 0.0131, Test Loss: 0.9144, Test Accuracy: 0.2707
# Epoch 298, Train Loss: 0.0129, Test Loss: 0.9139, Test Accuracy: 0.2707
# Epoch 299, Train Loss: 0.0128, Test Loss: 0.9135, Test Accuracy: 0.2703
# Epoch 300, Train Loss: 0.0127, Test Loss: 0.9131, Test Accuracy: 0.2703
# Epoch 301, Train Loss: 0.0126, Test Loss: 0.9127, Test Accuracy: 0.2703
# Epoch 302, Train Loss: 0.0125, Test Loss: 0.9123, Test Accuracy: 0.2703
# Epoch 303, Train Loss: 0.0124, Test Loss: 0.9119, Test Accuracy: 0.2703
# Epoch 304, Train Loss: 0.0123, Test Loss: 0.9115, Test Accuracy: 0.2703
# Epoch 305, Train Loss: 0.0122, Test Loss: 0.9111, Test Accuracy: 0.2707
# Epoch 306, Train Loss: 0.0121, Test Loss: 0.9107, Test Accuracy: 0.2707
# Epoch 307, Train Loss: 0.0120, Test Loss: 0.9103, Test Accuracy: 0.2707
# Epoch 308, Train Loss: 0.0119, Test Loss: 0.9099, Test Accuracy: 0.2707
# Epoch 309, Train Loss: 0.0118, Test Loss: 0.9095, Test Accuracy: 0.2707
# Epoch 310, Train Loss: 0.0117, Test Loss: 0.9091, Test Accuracy: 0.2707
# Epoch 311, Train Loss: 0.0116, Test Loss: 0.9088, Test Accuracy: 0.2707
# Epoch 312, Train Loss: 0.0116, Test Loss: 0.9084, Test Accuracy: 0.2707
# Epoch 313, Train Loss: 0.0115, Test Loss: 0.9080, Test Accuracy: 0.2707
# Epoch 314, Train Loss: 0.0114, Test Loss: 0.9076, Test Accuracy: 0.2707
# Epoch 315, Train Loss: 0.0113, Test Loss: 0.9073, Test Accuracy: 0.2707
# Epoch 316, Train Loss: 0.0112, Test Loss: 0.9069, Test Accuracy: 0.2707
# Epoch 317, Train Loss: 0.0111, Test Loss: 0.9066, Test Accuracy: 0.2707
# Epoch 318, Train Loss: 0.0110, Test Loss: 0.9062, Test Accuracy: 0.2707
# Epoch 319, Train Loss: 0.0109, Test Loss: 0.9058, Test Accuracy: 0.2707
# Epoch 320, Train Loss: 0.0109, Test Loss: 0.9055, Test Accuracy: 0.2707
# Epoch 321, Train Loss: 0.0108, Test Loss: 0.9051, Test Accuracy: 0.2707
# Epoch 322, Train Loss: 0.0107, Test Loss: 0.9048, Test Accuracy: 0.2703
# Epoch 323, Train Loss: 0.0106, Test Loss: 0.9045, Test Accuracy: 0.2703
# Epoch 324, Train Loss: 0.0105, Test Loss: 0.9041, Test Accuracy: 0.2703
# Epoch 325, Train Loss: 0.0105, Test Loss: 0.9038, Test Accuracy: 0.2703
# Epoch 326, Train Loss: 0.0104, Test Loss: 0.9034, Test Accuracy: 0.2703
# Epoch 327, Train Loss: 0.0103, Test Loss: 0.9031, Test Accuracy: 0.2703
# Epoch 328, Train Loss: 0.0102, Test Loss: 0.9028, Test Accuracy: 0.2703
# Epoch 329, Train Loss: 0.0101, Test Loss: 0.9024, Test Accuracy: 0.2699
# Epoch 330, Train Loss: 0.0101, Test Loss: 0.9021, Test Accuracy: 0.2699
# Epoch 331, Train Loss: 0.0100, Test Loss: 0.9018, Test Accuracy: 0.2699
# Epoch 332, Train Loss: 0.0099, Test Loss: 0.9015, Test Accuracy: 0.2699
# Epoch 333, Train Loss: 0.0099, Test Loss: 0.9012, Test Accuracy: 0.2699
# Epoch 334, Train Loss: 0.0098, Test Loss: 0.9009, Test Accuracy: 0.2699
# Epoch 335, Train Loss: 0.0097, Test Loss: 0.9005, Test Accuracy: 0.2699
# Epoch 336, Train Loss: 0.0096, Test Loss: 0.9002, Test Accuracy: 0.2696
# Epoch 337, Train Loss: 0.0096, Test Loss: 0.8999, Test Accuracy: 0.2692
# Epoch 338, Train Loss: 0.0095, Test Loss: 0.8996, Test Accuracy: 0.2692
# Epoch 339, Train Loss: 0.0094, Test Loss: 0.8993, Test Accuracy: 0.2692
# Epoch 340, Train Loss: 0.0094, Test Loss: 0.8990, Test Accuracy: 0.2692
# Epoch 341, Train Loss: 0.0093, Test Loss: 0.8987, Test Accuracy: 0.2692
# Epoch 342, Train Loss: 0.0092, Test Loss: 0.8984, Test Accuracy: 0.2692
# Epoch 343, Train Loss: 0.0092, Test Loss: 0.8981, Test Accuracy: 0.2692
# Epoch 344, Train Loss: 0.0091, Test Loss: 0.8978, Test Accuracy: 0.2692
# Epoch 345, Train Loss: 0.0090, Test Loss: 0.8975, Test Accuracy: 0.2692
# Epoch 346, Train Loss: 0.0090, Test Loss: 0.8972, Test Accuracy: 0.2692
# Epoch 347, Train Loss: 0.0089, Test Loss: 0.8970, Test Accuracy: 0.2692
# Epoch 348, Train Loss: 0.0089, Test Loss: 0.8967, Test Accuracy: 0.2692
# Epoch 349, Train Loss: 0.0088, Test Loss: 0.8964, Test Accuracy: 0.2692
# Epoch 350, Train Loss: 0.0087, Test Loss: 0.8961, Test Accuracy: 0.2692
# Epoch 351, Train Loss: 0.0087, Test Loss: 0.8958, Test Accuracy: 0.2692
# Epoch 352, Train Loss: 0.0086, Test Loss: 0.8956, Test Accuracy: 0.2692
# Epoch 353, Train Loss: 0.0086, Test Loss: 0.8953, Test Accuracy: 0.2692
# Epoch 354, Train Loss: 0.0085, Test Loss: 0.8950, Test Accuracy: 0.2692
# Epoch 355, Train Loss: 0.0084, Test Loss: 0.8947, Test Accuracy: 0.2692
# Epoch 356, Train Loss: 0.0084, Test Loss: 0.8945, Test Accuracy: 0.2688
# Epoch 357, Train Loss: 0.0083, Test Loss: 0.8942, Test Accuracy: 0.2688
# Epoch 358, Train Loss: 0.0083, Test Loss: 0.8939, Test Accuracy: 0.2688
# Epoch 359, Train Loss: 0.0082, Test Loss: 0.8937, Test Accuracy: 0.2688
# Epoch 360, Train Loss: 0.0082, Test Loss: 0.8934, Test Accuracy: 0.2688
# Epoch 361, Train Loss: 0.0081, Test Loss: 0.8932, Test Accuracy: 0.2688
# Epoch 362, Train Loss: 0.0081, Test Loss: 0.8929, Test Accuracy: 0.2688
# Epoch 363, Train Loss: 0.0080, Test Loss: 0.8927, Test Accuracy: 0.2688
# Epoch 364, Train Loss: 0.0080, Test Loss: 0.8924, Test Accuracy: 0.2688
# Epoch 365, Train Loss: 0.0079, Test Loss: 0.8922, Test Accuracy: 0.2688
# Epoch 366, Train Loss: 0.0079, Test Loss: 0.8919, Test Accuracy: 0.2688
# Epoch 367, Train Loss: 0.0078, Test Loss: 0.8917, Test Accuracy: 0.2688
# Epoch 368, Train Loss: 0.0078, Test Loss: 0.8914, Test Accuracy: 0.2688
# Epoch 369, Train Loss: 0.0077, Test Loss: 0.8912, Test Accuracy: 0.2688
# Epoch 370, Train Loss: 0.0077, Test Loss: 0.8909, Test Accuracy: 0.2688
# Epoch 371, Train Loss: 0.0076, Test Loss: 0.8907, Test Accuracy: 0.2688
# Epoch 372, Train Loss: 0.0076, Test Loss: 0.8904, Test Accuracy: 0.2688
# Epoch 373, Train Loss: 0.0075, Test Loss: 0.8902, Test Accuracy: 0.2688
# Epoch 374, Train Loss: 0.0075, Test Loss: 0.8900, Test Accuracy: 0.2688
# Epoch 375, Train Loss: 0.0074, Test Loss: 0.8897, Test Accuracy: 0.2688
# Epoch 376, Train Loss: 0.0074, Test Loss: 0.8895, Test Accuracy: 0.2688
# Epoch 377, Train Loss: 0.0073, Test Loss: 0.8893, Test Accuracy: 0.2688
# Epoch 378, Train Loss: 0.0073, Test Loss: 0.8890, Test Accuracy: 0.2688
# Epoch 379, Train Loss: 0.0072, Test Loss: 0.8888, Test Accuracy: 0.2688
# Epoch 380, Train Loss: 0.0072, Test Loss: 0.8886, Test Accuracy: 0.2685
# Epoch 381, Train Loss: 0.0071, Test Loss: 0.8884, Test Accuracy: 0.2685
# Epoch 382, Train Loss: 0.0071, Test Loss: 0.8881, Test Accuracy: 0.2685
# Epoch 383, Train Loss: 0.0071, Test Loss: 0.8879, Test Accuracy: 0.2685
# Epoch 384, Train Loss: 0.0070, Test Loss: 0.8877, Test Accuracy: 0.2685
# Epoch 385, Train Loss: 0.0070, Test Loss: 0.8875, Test Accuracy: 0.2685
# Epoch 386, Train Loss: 0.0069, Test Loss: 0.8873, Test Accuracy: 0.2685
# Epoch 387, Train Loss: 0.0069, Test Loss: 0.8870, Test Accuracy: 0.2685
# Epoch 388, Train Loss: 0.0068, Test Loss: 0.8868, Test Accuracy: 0.2685
# Epoch 389, Train Loss: 0.0068, Test Loss: 0.8866, Test Accuracy: 0.2685
# Epoch 390, Train Loss: 0.0068, Test Loss: 0.8864, Test Accuracy: 0.2685
# Epoch 391, Train Loss: 0.0067, Test Loss: 0.8862, Test Accuracy: 0.2685
# Epoch 392, Train Loss: 0.0067, Test Loss: 0.8860, Test Accuracy: 0.2685
# Epoch 393, Train Loss: 0.0066, Test Loss: 0.8858, Test Accuracy: 0.2688
# Epoch 394, Train Loss: 0.0066, Test Loss: 0.8856, Test Accuracy: 0.2688
# Epoch 395, Train Loss: 0.0066, Test Loss: 0.8854, Test Accuracy: 0.2688
# Epoch 396, Train Loss: 0.0065, Test Loss: 0.8852, Test Accuracy: 0.2688
# Epoch 397, Train Loss: 0.0065, Test Loss: 0.8850, Test Accuracy: 0.2688
# Epoch 398, Train Loss: 0.0064, Test Loss: 0.8848, Test Accuracy: 0.2688
# Epoch 399, Train Loss: 0.0064, Test Loss: 0.8846, Test Accuracy: 0.2688
# Epoch 400, Train Loss: 0.0064, Test Loss: 0.8844, Test Accuracy: 0.2688
# Epoch 401, Train Loss: 0.0063, Test Loss: 0.8842, Test Accuracy: 0.2688
# Epoch 402, Train Loss: 0.0063, Test Loss: 0.8840, Test Accuracy: 0.2688
# Epoch 403, Train Loss: 0.0063, Test Loss: 0.8838, Test Accuracy: 0.2688
# Epoch 404, Train Loss: 0.0062, Test Loss: 0.8836, Test Accuracy: 0.2688
# Epoch 405, Train Loss: 0.0062, Test Loss: 0.8834, Test Accuracy: 0.2688
# Epoch 406, Train Loss: 0.0061, Test Loss: 0.8832, Test Accuracy: 0.2688
# Epoch 407, Train Loss: 0.0061, Test Loss: 0.8830, Test Accuracy: 0.2688
# Epoch 408, Train Loss: 0.0061, Test Loss: 0.8828, Test Accuracy: 0.2688
# Epoch 409, Train Loss: 0.0060, Test Loss: 0.8826, Test Accuracy: 0.2688
# Epoch 410, Train Loss: 0.0060, Test Loss: 0.8825, Test Accuracy: 0.2688
# Epoch 411, Train Loss: 0.0060, Test Loss: 0.8823, Test Accuracy: 0.2688
# Epoch 412, Train Loss: 0.0059, Test Loss: 0.8821, Test Accuracy: 0.2688
# Epoch 413, Train Loss: 0.0059, Test Loss: 0.8819, Test Accuracy: 0.2688
# Epoch 414, Train Loss: 0.0059, Test Loss: 0.8817, Test Accuracy: 0.2688
# Epoch 415, Train Loss: 0.0058, Test Loss: 0.8815, Test Accuracy: 0.2692
# Epoch 416, Train Loss: 0.0058, Test Loss: 0.8814, Test Accuracy: 0.2692
# Epoch 417, Train Loss: 0.0058, Test Loss: 0.8812, Test Accuracy: 0.2696
# Epoch 418, Train Loss: 0.0057, Test Loss: 0.8810, Test Accuracy: 0.2696
# Epoch 419, Train Loss: 0.0057, Test Loss: 0.8808, Test Accuracy: 0.2696
# Epoch 420, Train Loss: 0.0057, Test Loss: 0.8807, Test Accuracy: 0.2696
# Epoch 421, Train Loss: 0.0057, Test Loss: 0.8805, Test Accuracy: 0.2696
# Epoch 422, Train Loss: 0.0056, Test Loss: 0.8803, Test Accuracy: 0.2696
# Epoch 423, Train Loss: 0.0056, Test Loss: 0.8801, Test Accuracy: 0.2696
# Epoch 424, Train Loss: 0.0056, Test Loss: 0.8800, Test Accuracy: 0.2696
# Epoch 425, Train Loss: 0.0055, Test Loss: 0.8798, Test Accuracy: 0.2696
# Epoch 426, Train Loss: 0.0055, Test Loss: 0.8796, Test Accuracy: 0.2696
# Epoch 427, Train Loss: 0.0055, Test Loss: 0.8795, Test Accuracy: 0.2696
# Epoch 428, Train Loss: 0.0054, Test Loss: 0.8793, Test Accuracy: 0.2696
# Epoch 429, Train Loss: 0.0054, Test Loss: 0.8791, Test Accuracy: 0.2696
# Epoch 430, Train Loss: 0.0054, Test Loss: 0.8790, Test Accuracy: 0.2696
# Epoch 431, Train Loss: 0.0054, Test Loss: 0.8788, Test Accuracy: 0.2696
# Epoch 432, Train Loss: 0.0053, Test Loss: 0.8786, Test Accuracy: 0.2696
# Epoch 433, Train Loss: 0.0053, Test Loss: 0.8785, Test Accuracy: 0.2696
# Epoch 434, Train Loss: 0.0053, Test Loss: 0.8783, Test Accuracy: 0.2696
# Epoch 435, Train Loss: 0.0052, Test Loss: 0.8782, Test Accuracy: 0.2696
# Epoch 436, Train Loss: 0.0052, Test Loss: 0.8780, Test Accuracy: 0.2696
# Epoch 437, Train Loss: 0.0052, Test Loss: 0.8779, Test Accuracy: 0.2696
# Epoch 438, Train Loss: 0.0052, Test Loss: 0.8777, Test Accuracy: 0.2696
# Epoch 439, Train Loss: 0.0051, Test Loss: 0.8775, Test Accuracy: 0.2696
# Epoch 440, Train Loss: 0.0051, Test Loss: 0.8774, Test Accuracy: 0.2696
# Epoch 441, Train Loss: 0.0051, Test Loss: 0.8772, Test Accuracy: 0.2696
# Epoch 442, Train Loss: 0.0050, Test Loss: 0.8771, Test Accuracy: 0.2696
# Epoch 443, Train Loss: 0.0050, Test Loss: 0.8769, Test Accuracy: 0.2696
# Epoch 444, Train Loss: 0.0050, Test Loss: 0.8768, Test Accuracy: 0.2696
# Epoch 445, Train Loss: 0.0050, Test Loss: 0.8766, Test Accuracy: 0.2696
# Epoch 446, Train Loss: 0.0049, Test Loss: 0.8765, Test Accuracy: 0.2696
# Epoch 447, Train Loss: 0.0049, Test Loss: 0.8763, Test Accuracy: 0.2703
# Epoch 448, Train Loss: 0.0049, Test Loss: 0.8762, Test Accuracy: 0.2703
# Epoch 449, Train Loss: 0.0049, Test Loss: 0.8761, Test Accuracy: 0.2703
# Epoch 450, Train Loss: 0.0048, Test Loss: 0.8759, Test Accuracy: 0.2703
# Epoch 451, Train Loss: 0.0048, Test Loss: 0.8758, Test Accuracy: 0.2703
# Epoch 452, Train Loss: 0.0048, Test Loss: 0.8756, Test Accuracy: 0.2703
# Epoch 453, Train Loss: 0.0048, Test Loss: 0.8755, Test Accuracy: 0.2703
# Epoch 454, Train Loss: 0.0047, Test Loss: 0.8753, Test Accuracy: 0.2703
# Epoch 455, Train Loss: 0.0047, Test Loss: 0.8752, Test Accuracy: 0.2703
# Epoch 456, Train Loss: 0.0047, Test Loss: 0.8751, Test Accuracy: 0.2703
# Epoch 457, Train Loss: 0.0047, Test Loss: 0.8749, Test Accuracy: 0.2703
# Epoch 458, Train Loss: 0.0047, Test Loss: 0.8748, Test Accuracy: 0.2703
# Epoch 459, Train Loss: 0.0046, Test Loss: 0.8746, Test Accuracy: 0.2703
# Epoch 460, Train Loss: 0.0046, Test Loss: 0.8745, Test Accuracy: 0.2703
# Epoch 461, Train Loss: 0.0046, Test Loss: 0.8744, Test Accuracy: 0.2703
# Epoch 462, Train Loss: 0.0046, Test Loss: 0.8742, Test Accuracy: 0.2703
# Epoch 463, Train Loss: 0.0045, Test Loss: 0.8741, Test Accuracy: 0.2703
# Epoch 464, Train Loss: 0.0045, Test Loss: 0.8740, Test Accuracy: 0.2703
# Epoch 465, Train Loss: 0.0045, Test Loss: 0.8738, Test Accuracy: 0.2703
# Epoch 466, Train Loss: 0.0045, Test Loss: 0.8737, Test Accuracy: 0.2703
# Epoch 467, Train Loss: 0.0044, Test Loss: 0.8736, Test Accuracy: 0.2703
# Epoch 468, Train Loss: 0.0044, Test Loss: 0.8734, Test Accuracy: 0.2703
# Epoch 469, Train Loss: 0.0044, Test Loss: 0.8733, Test Accuracy: 0.2703
# Epoch 470, Train Loss: 0.0044, Test Loss: 0.8732, Test Accuracy: 0.2703
# Epoch 471, Train Loss: 0.0044, Test Loss: 0.8731, Test Accuracy: 0.2703
# Epoch 472, Train Loss: 0.0043, Test Loss: 0.8729, Test Accuracy: 0.2703
# Epoch 473, Train Loss: 0.0043, Test Loss: 0.8728, Test Accuracy: 0.2703
# Epoch 474, Train Loss: 0.0043, Test Loss: 0.8727, Test Accuracy: 0.2703
# Epoch 475, Train Loss: 0.0043, Test Loss: 0.8725, Test Accuracy: 0.2703
# Epoch 476, Train Loss: 0.0043, Test Loss: 0.8724, Test Accuracy: 0.2703
# Epoch 477, Train Loss: 0.0042, Test Loss: 0.8723, Test Accuracy: 0.2703
# Epoch 478, Train Loss: 0.0042, Test Loss: 0.8722, Test Accuracy: 0.2703
# Epoch 479, Train Loss: 0.0042, Test Loss: 0.8721, Test Accuracy: 0.2703
# Epoch 480, Train Loss: 0.0042, Test Loss: 0.8719, Test Accuracy: 0.2703
# Epoch 481, Train Loss: 0.0042, Test Loss: 0.8718, Test Accuracy: 0.2703
# Epoch 482, Train Loss: 0.0041, Test Loss: 0.8717, Test Accuracy: 0.2703
# Epoch 483, Train Loss: 0.0041, Test Loss: 0.8716, Test Accuracy: 0.2703
# Epoch 484, Train Loss: 0.0041, Test Loss: 0.8714, Test Accuracy: 0.2703
# Epoch 485, Train Loss: 0.0041, Test Loss: 0.8713, Test Accuracy: 0.2703
# Epoch 486, Train Loss: 0.0041, Test Loss: 0.8712, Test Accuracy: 0.2707
# Epoch 487, Train Loss: 0.0040, Test Loss: 0.8711, Test Accuracy: 0.2707
# Epoch 488, Train Loss: 0.0040, Test Loss: 0.8710, Test Accuracy: 0.2707
# Epoch 489, Train Loss: 0.0040, Test Loss: 0.8709, Test Accuracy: 0.2707
# Epoch 490, Train Loss: 0.0040, Test Loss: 0.8707, Test Accuracy: 0.2707
# Epoch 491, Train Loss: 0.0040, Test Loss: 0.8706, Test Accuracy: 0.2707
# Epoch 492, Train Loss: 0.0039, Test Loss: 0.8705, Test Accuracy: 0.2710
# Epoch 493, Train Loss: 0.0039, Test Loss: 0.8704, Test Accuracy: 0.2710
# Epoch 494, Train Loss: 0.0039, Test Loss: 0.8703, Test Accuracy: 0.2710
# Epoch 495, Train Loss: 0.0039, Test Loss: 0.8702, Test Accuracy: 0.2714
# Epoch 496, Train Loss: 0.0039, Test Loss: 0.8701, Test Accuracy: 0.2714
# Epoch 497, Train Loss: 0.0039, Test Loss: 0.8700, Test Accuracy: 0.2714
# Epoch 498, Train Loss: 0.0038, Test Loss: 0.8698, Test Accuracy: 0.2714
# Epoch 499, Train Loss: 0.0038, Test Loss: 0.8697, Test Accuracy: 0.2714
# Epoch 500, Train Loss: 0.0038, Test Loss: 0.8696, Test Accuracy: 0.2714

# %%
# LapPE and SignNet
lap_pe = laplacian_positional_encoding(data.edge_index, data.num_nodes, k=10).cuda()
sign_net = SignNet(lap_pe.shape[1], 64).cuda()
lap_pe_transformed = sign_net(lap_pe)

# Graph Transformer
graph_transformer = GraphTransformer(in_channels=64, out_channels=32).cuda()
x_transformed = graph_transformer(lap_pe_transformed, data.edge_index.cuda())

print("Transformed embeddings shape:", x_transformed.shape)
# Out:
# Transformed embeddings shape: torch.Size([2708, 256])
